# %% [markdown]
# This example implements the first model from "Modeling civil violence: An agent-based computational approach," by Joshua Epstein.  The paper (pdf) can be found [here](http://www.uvm.edu/~pdodds/files/papers/others/2002/epstein2002a.pdf).
#
# The model consists of two types of agents: "Citizens" (called "Agents" in the paper) and "Cops."  Agents decide whether or not to rebel by weighing their unhappiness ('grievance') against the risk of rebelling, which they estimate by comparing the local ratio of rebels to cops.

# %%
# %matplotlib inline

# from epstein_civil_violence.model import EpsteinCivilViolence
import sys
import os

# Add the path to the parent folder of 'epstein_civil_violence'
sys.path.append(os.path.abspath(".."))

from epstein_civil_violence.model import EpsteinCivilViolence

# %%
model = EpsteinCivilViolence(
    height=40,
    width=40,
    citizen_density=0.7,
    cop_density=0.074,
    citizen_vision=7,
    cop_vision=7,
    legitimacy=0.8,
    max_jail_term=1000,
    max_iters=1000,
    capacity=200,
    occupation=0,
    seed = 55
)  # cap the number of steps the model takes
model.run_model()

# %% [markdown]
# The model's data collector counts the number of citizens who are Active (in rebellion), Jailed, or Quiescent after each step.

# %%
model_out = model.datacollector.get_model_vars_dataframe()
print(model_out[:30])
boeb= model_out[model_out['active']>50].index.tolist()
print(boeb)
# Out:
#     active  quiet  arrested
# 0        0   1114         0
# 1        3   1082        29
# 2        0   1082        32
# 3        0   1082        32
# 4        0   1082        32
# 5        0   1082        32
# 6        0   1081        33
# 7        0   1081        33
# 8        0   1081        33
# 9        0   1081        33
# 10       0   1081        33
# 11       0   1081        33
# 12       0   1081        33
# 13       0   1081        33
# 14       0   1081        33
# 15       0   1081        33
# 16       0   1081        33
# 17       0   1081        33
# 18       0   1081        33
# 19       0   1081        33
# 20       0   1081        33
# 21       0   1081        33
# 22       0   1081        33
# 23       0   1081        33
# 24       0   1081        33
# 25       0   1081        33
# 26       0   1081        33
# 27       0   1081        33
# 28       0   1081        33
# 29       0   1081        33
# []

# %%
ax = model_out.plot()
ax.set_title("Citizen Condition Over Time")
ax.set_xlabel("Step")
ax.set_ylabel("Number of Citizens")
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))
