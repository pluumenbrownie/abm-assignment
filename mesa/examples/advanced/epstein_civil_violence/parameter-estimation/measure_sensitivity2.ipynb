# %%
import contextlib
import os
from random import choices
import string

import pandas as pd
from constants import max_steps, replicates

from mesa.batchrunner import batch_run_not_stupid
from mesa.examples.advanced.epstein_civil_violence.model import EpsteinCivilViolence

# %%
files = [f"data_{x:04}.csv" for x in range(20)]
files
# Out:
# ['data_0000.csv', 'data_0001.csv', 'data_0002.csv']

# %%
def in_file(filename: str):
    return f"inputs_new/{filename}"


def out_file(filename: str, identifier: str):
    return f"outputs_new/{identifier}_{filename}"

# %%
def run_for_file(filename: str, identifier: str):
    data = pd.read_csv(in_file(filename), index_col=0)
    print(f"Loaded {filename} with {len(data)} parameter samples.")

    result = batch_run_not_stupid(
        EpsteinCivilViolence,
        parameters=data,
        iterations=replicates,
        max_steps=max_steps,
        number_processes=None,
        display_progress=True,
    )

    result_df = pd.DataFrame(result)
    with contextlib.suppress(FileExistsError):
        os.mkdir("outputs")
    result_df.to_csv(out_file(filename, identifier))

# %%
while True:
    identifier = str(choices(string.ascii_letters + string.digits, k=8))
    print(f"Starting run {identifier}.")
    for file in files:
        run_for_file(file, identifier)
# Out:
# Loaded 1024 parameter samples.
#   0%|          | 0/10240 [00:00<?, ?it/s]
# Loaded 1024 parameter samples.
#   0%|          | 0/10240 [00:00<?, ?it/s]
# Process SpawnPoolWorker-1452:
# Process SpawnPoolWorker-1450:
# Process SpawnPoolWorker-1453:
# Process SpawnPoolWorker-1454:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process SpawnPoolWorker-1449:
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 266, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 191, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 165, in step
#     self.update_estimated_arrest_probability_and_observed_violence()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 189, in update_estimated_arrest_probability_and_observed_violence
#     actives_in_vision += self.prob_quiet
#     ^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 266, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 191, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 167, in step
#     self.move(self.prob_quiet)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 58, in move
#     values.append(prob_quite / quiet_count)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process SpawnPoolWorker-1456:
# Process SpawnPoolWorker-1451:
# Traceback (most recent call last):
# Process SpawnPoolWorker-1455:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 266, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 191, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 167, in step
#     self.move(self.prob_quiet)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 48, in move
#     agents = neighbor.neighborhood.agents
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell_collection.py", line 97, in agents
#     return itertools.chain.from_iterable(self._cells.values())
#                                          ~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 266, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 191, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 167, in step
#     self.move(self.prob_quiet)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 48, in move
#     agents = neighbor.neighborhood.agents
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell_collection.py", line 97, in agents
#     return itertools.chain.from_iterable(self._cells.values())
#                                          ~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 266, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 191, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 167, in step
#     self.move(self.prob_quiet)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 73, in move
#     self.move_to(new_pos)
#     ~~~~~~~~~~~~^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell_agent.py", line 56, in move_to
#     def move_to(self: HasCellProtocol, cell: Cell) -> None:
#
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 266, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 191, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 164, in step
#     self.update_neighbors()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 37, in update_neighbors
#     self.empty_neighbors = [c for c in self.neighborhood if c.is_empty]
#                             ^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 266, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 191, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 165, in step
#     self.update_estimated_arrest_probability_and_observed_violence()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 189, in update_estimated_arrest_probability_and_observed_violence
#     actives_in_vision += self.prob_quiet
#     ^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 for file in files:
# ----> 2     run_for_file(file)
#
# Cell In[9], line 5, in run_for_file(filename)
#       2 data = pd.read_csv(in_file(filename), index_col=0)
#       3 print(f"Loaded {len(data)} parameter samples.")
# ----> 5 result = batch_run_not_stupid(
#       6     EpsteinCivilViolence,
#       7     parameters=data,
#       8     iterations=replicates,
#       9     max_steps=max_steps,
#      10     number_processes=None,
#      11     display_progress=True,
#      12 )
#      14 # ripley_police = np.zeros((len(result), len(result[0]["ripley_l_police"])))
#      15 # ripley_citizen = np.zeros((len(result), len(result[0]["ripley_l_citizen"])))
#      16 # for nr, res in enumerate(result):
#    (...)     19 #     ripley_citizen[nr] = res["ripley_l_citizen"]
#      20 #     del res["ripley_l_citizen"]
#      22 result_df = pd.DataFrame(result)
#
# File ~/Documents/external_repos/abm-assignment/mesa/batchrunner.py:92, in batch_run_not_stupid(model_cls, parameters, number_processes, iterations, data_collection_period, max_steps, display_progress)
#      89     results = []
#      90     for iteration in runs_list:
#      91         results.extend(
# ---> 92             _inner_not_stupid(
#      93                 model_cls,
#      94                 number_processes,
#      95                 data_collection_period,
#      96                 max_steps,
#      97                 pbar,
#      98                 iteration,
#      99             )
#     100         )
#     102 return results
#
# File ~/Documents/external_repos/abm-assignment/mesa/batchrunner.py:130, in _inner_not_stupid(model_cls, number_processes, data_collection_period, max_steps, pbar, runs_list)
#     128 else:
#     129     with Pool(number_processes) as p:
# --> 130         for data in p.imap_unordered(process_func, runs_list):
#     131             results.extend(data)
#     132             pbar.update()
#
# File ~/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~/.local/share/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:
