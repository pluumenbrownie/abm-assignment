# %%
import contextlib
import os
import string
from random import choices

import pandas as pd
from constants import max_steps, replicates

from mesa.batchrunner import batch_run_not_stupid
from mesa.examples.advanced.epstein_civil_violence.model import EpsteinCivilViolence

# %%
# optionally change for partial run
files = [f"data_{x:04}.csv" for x in range(20)]
files
# Out:
# ['data_0000.csv',
#  'data_0001.csv',
#  'data_0002.csv',
#  'data_0003.csv',
#  'data_0004.csv',
#  'data_0005.csv',
#  'data_0006.csv',
#  'data_0007.csv',
#  'data_0008.csv',
#  'data_0009.csv',
#  'data_0010.csv',
#  'data_0011.csv',
#  'data_0012.csv',
#  'data_0013.csv',
#  'data_0014.csv',
#  'data_0015.csv',
#  'data_0016.csv',
#  'data_0017.csv',
#  'data_0018.csv',
#  'data_0019.csv']

# %%
def in_file(filename: str):
    """Generates the path to the given input file.
    Args:
        filename: the name of the file"""
    return f"inputs_new/{filename}"


def out_file(filename: str, identifier: str):
    """Generates the path to the given output file.
    Args:
        filename: the name of the file.
        identifier: an unique identifier string add to the front of the name of
            the new file"""
    return f"outputs_new/{identifier}_{filename}"

# %%
def run_for_file(filename: str, identifier: str):
    """
    Calculate and save the results of simulations with the parameters in the file.
    Args:
        filename: the name of the parameter file
        identifier: an unique identifier to use when saving the results
    """
    data = pd.read_csv(in_file(filename), index_col=0)
    print(f"Loaded {filename} with {len(data)} parameter samples.")

    result = batch_run_not_stupid(
        EpsteinCivilViolence,
        parameters=data,
        iterations=replicates,
        max_steps=max_steps,
        number_processes=None,
        display_progress=True,
    )

    result_df = pd.DataFrame(result)

    # we just want the folder to exist
    with contextlib.suppress(FileExistsError):
        os.mkdir("outputs_new")
    result_df.to_csv(out_file(filename, identifier))

# %%
while True:
    identifier = "".join(choices(string.ascii_letters + string.digits, k=8))
    print(f"Starting run {identifier}.")
    for file in files:
        run_for_file(file, identifier)
# Out:
# Starting run sDFgvh4p.
# Loaded data_0000.csv with 256 parameter samples.
#   0%|          | 0/256 [00:00<?, ?it/s]
# Process SpawnPoolWorker-4942:
# Process SpawnPoolWorker-4939:
# Process SpawnPoolWorker-4944:
# Process SpawnPoolWorker-4940:
# Process SpawnPoolWorker-4936:
# Process SpawnPoolWorker-4938:
# Process SpawnPoolWorker-4934:
# Process SpawnPoolWorker-4933:
# Process SpawnPoolWorker-4937:
# Process SpawnPoolWorker-4941:
# Process SpawnPoolWorker-4935:
# Process SpawnPoolWorker-4943:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 164, in step
#     self.update_neighbors()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 37, in update_neighbors
#     self.empty_neighbors = [c for c in self.neighborhood if c.is_empty]
#                             ^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 258, in step
#     self.update_neighbors()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 37, in update_neighbors
#     self.empty_neighbors = [c for c in self.neighborhood if c.is_empty]
#                             ^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 167, in step
#     self.move(self.prob_quiet)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 48, in move
#     agents = neighbor.neighborhood.agents
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell_collection.py", line 97, in agents
#     return itertools.chain.from_iterable(self._cells.values())
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 164, in step
#     self.update_neighbors()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 37, in update_neighbors
#     self.empty_neighbors = [c for c in self.neighborhood if c.is_empty]
#                                                             ^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell.py", line 129, in is_empty
#     @property
#
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 164, in step
#     self.update_neighbors()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 37, in update_neighbors
#     self.empty_neighbors = [c for c in self.neighborhood if c.is_empty]
#                                                             ^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell.py", line 132, in is_empty
#     return len(self.agents) == 0
#                ^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell.py", line 142, in agents
#     return self._agents.copy()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 258, in step
#     self.update_neighbors()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 37, in update_neighbors
#     self.empty_neighbors = [c for c in self.neighborhood if c.is_empty]
#                                                             ^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell.py", line 132, in is_empty
#     return len(self.agents) == 0
#                ^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell.py", line 142, in agents
#     return self._agents.copy()
#            ~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 164, in step
#     self.update_neighbors()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 37, in update_neighbors
#     self.empty_neighbors = [c for c in self.neighborhood if c.is_empty]
#                             ^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 165, in step
#     self.update_estimated_arrest_probability_and_observed_violence()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 189, in update_estimated_arrest_probability_and_observed_violence
#     actives_in_vision += self.prob_quiet
#     ^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 167, in step
#     self.move(self.prob_quiet)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 59, in move
#     if sum(values) == 0:
#        ~~~^^^^^^^^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 167, in step
#     self.move(self.prob_quiet)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 56, in move
#     quiet_count += 1
#     ^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 164, in step
#     self.update_neighbors()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 35, in update_neighbors
#     self.neighborhood = self.cell.get_neighborhood(radius=self.vision)
#                         ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/batchrunner.py", line 279, in _model_run_func
#     model.step()
#     ~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/model.py", line 122, in _wrapped_step
#     self._user_step(*args, **kwargs)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/model.py", line 179, in step
#     self.agents.shuffle_do("step")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/agent.py", line 347, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 164, in step
#     self.update_neighbors()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/examples/advanced/epstein_civil_violence/agents.py", line 35, in update_neighbors
#     self.neighborhood = self.cell.get_neighborhood(radius=self.vision)
#                         ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell.py", line 175, in get_neighborhood
#     self._neighborhood(radius=radius, include_center=include_center),
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell.py", line 201, in _neighborhood
#     neighbor._neighborhood(radius - 1, include_center=True)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell.py", line 201, in _neighborhood
#     neighbor._neighborhood(radius - 1, include_center=True)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell.py", line 201, in _neighborhood
#     neighbor._neighborhood(radius - 1, include_center=True)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 3 more times]
#   File "/home/wessel/Documents/external_repos/abm-assignment/mesa/discrete_space/cell.py", line 190, in _neighborhood
#     neighbor: neighbor._agents for neighbor in self.connections.values()
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 5
#       3 print(f"Starting run {identifier}.")
#       4 for file in files:
# ----> 5     run_for_file(file, identifier)
#
# Cell In[14], line 11, in run_for_file(filename, identifier)
#       8 data = pd.read_csv(in_file(filename), index_col=0)
#       9 print(f"Loaded {filename} with {len(data)} parameter samples.")
# ---> 11 result = batch_run_not_stupid(
#      12     EpsteinCivilViolence,
#      13     parameters=data,
#      14     iterations=replicates,
#      15     max_steps=max_steps,
#      16     number_processes=None,
#      17     display_progress=True,
#      18 )
#      20 result_df = pd.DataFrame(result)
#      22 # we just want the folder to exist
#
# File ~/Documents/external_repos/abm-assignment/mesa/batchrunner.py:92, in batch_run_not_stupid(model_cls, parameters, number_processes, iterations, data_collection_period, max_steps, display_progress)
#      89     results = []
#      90     for iteration in runs_list:
#      91         results.extend(
# ---> 92             _inner_not_stupid(
#      93                 model_cls,
#      94                 number_processes,
#      95                 data_collection_period,
#      96                 max_steps,
#      97                 pbar,
#      98                 iteration,
#      99             )
#     100         )
#     102 return results
#
# File ~/Documents/external_repos/abm-assignment/mesa/batchrunner.py:130, in _inner_not_stupid(model_cls, number_processes, data_collection_period, max_steps, pbar, runs_list)
#     105 def _inner_not_stupid(
#     106     model_cls: type[Model],
#     107     number_processes: int | None,
#    (...)    111     runs_list: list[tuple[int, int, dict[str, Any]]],
#     112 ):
#     113     """I hope splitting this solves the memory leak.
#     114     Args:
#     115         model_cls (Type[Model]): The model class to batch-run
#    (...)    125             parameters for a given run.
#     126     """
#     127     process_func = partial(
#     128         _model_run_func,
#     129         model_cls,
# --> 130         max_steps=max_steps,
#     131         data_collection_period=data_collection_period,
#     132     )
#     134     results: list[dict[str, Any]] = []
#     136     if number_processes == 1:
#
# File ~/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~/.local/share/uv/python/cpython-3.13.4-linux-x86_64-gnu/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:
